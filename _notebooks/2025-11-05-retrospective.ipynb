# %% [raw]
# ---
# title: Alice's Tri 1 Retrospective
# comments: true
# layout: post
# permalink: /retrospectiveblog
# author: Alice Li
# ---

# %% [markdown]
# # Looking Back and Moving Forward

# %% [markdown]
# ## 🧭 Comparing Myself to the Beginning of the Year
#
# At the start of the year, I didn’t really understand how code worked, I just followed the steps without knowing *why* things happened.
#
# Now, after learning **Big Idea 3: Algorithms and Programming**, I can confidently explain and apply key coding concepts:
#
# -  **Variables:** I learned how to store, update, and use data efficiently in programs.
#
# -  **Functions / Procedures:** I can group code into reusable blocks that make programs cleaner and easier to manage.
#
# -  **Parameters:** I understand how parameters make procedures flexible so they can handle different inputs.
#
# -  **Loops and Conditionals:** I know how to use loops to repeat actions and conditionals to make decisions in an algorithm.
#
# -  **Calling and Combining Procedures:** I’ve practiced connecting one function’s output to another’s input to build more complex programs.
#
# - **Algorithm Design:** I can break big problems into smaller parts and write clear, step-by-step instructions for solving them.
#
#
# I’ve also grown in **collaboration** this year:
# -  Learned to explain my reasoning and communicate clearly when coding with others.
#
# - Worked through debugging and brainstorming as a team.
#
# - Divided tasks and helped others understand their parts of the project.
#
#
# Overall, I’ve gone from just *following code* to really *understanding and creating* it. I feel much more confident and creative as a problem solver.

# %% [markdown]
# ## 🏁 Remembering the Three Sprints
#
# Throughout this semester, each sprint helped me grow as a coder, problem solver, and designer. Here’s what I learned from each one:
#
# ---
#
# ### 🧰 **Tools Sprint**
#
# This sprint focused on learning the essential tools that real developers use every day. I learned how to set up my workspace, organize files, and share projects online.
#
# - 💻 Learned to use **VS Code** for writing, editing, and previewing my code efficiently.
# - 🌐 Practiced **HTML** for structure and **CSS** for styling web pages.
# - 🔗 Gained experience with **GitHub**, learning how to upload, version control, and publish projects.
# - 🚀 Created and deployed my first webpage — it was exciting to see my code live on the internet!
# - 🧭 Learned the importance of file paths, folder organization, and commenting my code for clarity.
#
# This sprint built the foundation for everything else — it helped me feel like an actual web developer.
#
# ---
#
# ### 💡 **Fundamentals of JavaScript/Python Sprint**
#
# This sprint was where I really started to **think like a programmer**. I began to understand how logic drives everything behind the scenes.
#
# -  Practiced **writing functions** to make code modular and reusable.
# - Used **variables** to store and manipulate data in both JavaScript and Python.
# -  Worked with **loops** and **conditionals** to automate processes and make programs dynamic.
# -  Learned about **input and output**, letting users interact with my code.
# -  Debugged errors by testing step-by-step and reading console messages carefully.
# -  Applied **problem decomposition** — breaking complex problems into smaller, solvable parts.
#
# This sprint helped me connect the logic I was writing to the actual outcomes I could see and interact with.
#
# ---
#
# ### 🌴 **West Coast Travel Quest**
#
# This was my favorite sprint because it combined creativity, storytelling, and coding skills all at once! I got to build a travel website that reflected my interests while using more advanced programming techniques.
#
#
# - Designed interactive **travel pages** using HTML, CSS, and JavaScript.
# -  Added **animations and transitions** to make the website feel alive and engaging.
# -  Learned how to **organize code** with reusable components and clean formatting.
# -  Practiced **testing and debugging** to make sure everything ran smoothly.
# -  Used design thinking to consider the **user experience (UI)** — how others would navigate and enjoy the site.
# - Showed me how front-end coding works
# - Incorporated images, hover effects, and buttons for a more dynamic visual story.
#
# This sprint made me realize that programming isn’t just about logic — it’s also a creative form of expression.
#
# Even though there were struggles, we perservered and it all came together at the end.
#
# ---
#
# Each sprint built on the last, helping me grow from learning basic syntax to designing interactive, meaningful projects.

# %% [markdown]
# ## Big Idea 3 Reflection
#
# ### 3.1 – Variables
# - Variables store information for later use in a program.
# - I learned how to assign values correctly.
# - Using clear, descriptive names makes code easier to read and maintain.
#
# ### 3.2 – Lists and Strings
# - Lists help manage complexity by storing many related items in one variable.
# - They can grow or shrink as needed and allow the same computation on all elements.
# - Strings and lists are both ordered sequences.
#
# ### 3.3 – Algorithms and Teaching
# - I created JavaScript and Python homework.
# - Learned about learning objectives and algorithms.
# - Taught others how algorithms work.
#
# ### 3.4 – Strings
# - Strings are sequences of characters inside quotes used to store text.
# - I learned to define strings in both Python and JavaScript.
# - Practiced using operations like upper, lower, slicing, and concatenation.
# - Learned how to create multiline strings.
#
# ### 3.5 – Boolean Expressions
# - Booleans help programs make decisions with True or False values.
# - Relational operators compare values, and modulus checks remainders.
# - Logical operators like not, and, or combine or flip conditions.
#
# ### 3.6 – Conditionals
# - Conditionals let programs make decisions based on conditions.
# - I used if, elif/else if, and else to control code flow.
# - Learned to use comparison and logical operators with Booleans.
#
# ### 3.7 – Nested Conditionals
# - Nested conditionals are if statements inside other if statements.
# - They help handle multiple related decisions in order.
# - Useful for complex logic like age checks or game conditions.
#
# ### 3.8 – Iteration
# - Iterations repeat code using loops.
# - For loops go through sequences, while loops repeat while a condition is True.
# - Loops can be nested or indexed with enumerate().
#
# ### 3.9 – Developing Algorithms
# - Algorithms are step-by-step instructions to solve problems.
# - Clear algorithms make code easier to understand, test, and debug.
# - Efficiency matters when designing algorithms.
#
# ### 3.10 – Lists
# - Lists organize and process multiple pieces of data.
# - I practiced adding, removing, and looping through list elements.
# - Lists make programs more flexible and dynamic.
#
# ### 3.12 – Calling Procedures
# - Calling procedures helps reuse code efficiently.
# - I learned to pass arguments into functions.
# - Functions simplify and organize complex programs.
#
# ### 3.13 – Developing Procedures
# - I learned how to define my own procedures.
# - Functions make programs cleaner and more organized.
# - Reusable code reduces errors and improves structure.
#
# ### 3.15 – Random Values
# - Random values add variety and unpredictability to programs.
# - Useful in games, simulations, and testing.
# - I learned how to generate and use random numbers in code.
#
# ### 3.17 – Algorithmic Efficiency
# - Algorithmic efficiency measures how fast and resourceful a program is.
# - Efficient algorithms save time and improve performance.
# - I learned to compare different approaches to find the best one.

# %% [markdown]
# ## 🏛️ Night at the Museum
#
# **Night at the Museum** was such a great experience because it gave me the chance to share my project with people outside of class and see their reactions in real time. ✨
#
# -  I enjoyed **presenting our West Coast Travel Quest project** and explaining how it worked — especially showing off the **interactive code** that made the animations and buttons respond to user actions.
#
# -  I liked being able to **teach visitors how the code behind the scenes created the visual effects**, like transitions and hover animations. It felt rewarding to help them understand that what looks simple on screen actually takes logic and creativity to build.
#
# - One of my favorite comments was when someone said my **UI design and animations looked “clean and professional.”** It made me proud of how much my coding and design skills have grown.
#
# - It was also fun collaborating with classmates during the showcase
#
# - Helping each other explain our projects and celebrating all the hard work we put in.
#
# Overall, the event showed me how much confidence I’ve gained this year. I didn’t just *show* my code — I was able to *explain* it clearly and get others excited about what we built. 🚀

# %% [markdown]
# <h2>Night at the Museum Pictures</h2>
#
# <div id="slideshow" style="max-width:400px;">
#   <img id="slide" src="images/ntm.png" alt="Night at the Museum" style="width:100%; border-radius:12px;">
#   <br>
#   <button onclick="prevImage()" style="margin-top:8px;">⬅️ Prev</button>
#   <button onclick="nextImage()">Next ➡️</button>
# </div>
#
# <script>
#   // Relative paths from this Markdown file
#   const images = [
#     "images/ntm.png",
#     "images/ntm2.png"
#   ];
#   let index = 0;
#   const slide = document.getElementById("slide");
#
#   function showImage(i) {
#     slide.src = images[i];
#   }
#
#   function nextImage() {
#     index = (index + 1) % images.length;
#     showImage(index);
#   }
#
#   function prevImage() {
#     index = (index - 1 + images.length) % images.length;
#     showImage(index);
#   }
# </script>

# %% [markdown]
# ## Next Steps: Travel Module Project
#
# For my next project, I want to continue building my **Travel Module** and make it more interactive and dynamic.
#
# - I plan to add **animations and smooth transitions** between destinations to make the experience feel like an actual journey.
#
# - I want to include a **navigation bar or map feature** that lets users explore different locations in any order, creating a more immersive experience.
#
# - If time allows, I’d love to connect it to **real-world data using an API**, such as live weather updates, maps, or travel images.
#
# - I’ll focus on improving **UI design** and **user experience** by keeping layouts consistent, readable, and visually appealing.
#
# - I also want to organize my code better with **functions and reusable components**, so it’s easier to maintain and expand later.
#
#
# Overall, my goal is to take what I learned from the West Coast Travel Quest and turn it into a more advanced project that combines creativity, interactivity, and real-world data.

# %% [markdown]
# ## What I Want to Learn Next in Computer Science
#
# Looking ahead, I want to continue building on the skills I’ve learned this year and explore new areas of computer science.
#
# - I want to learn more about **how front-end and back-end systems work together**, including how data moves between a website and a server.
#
# - I’m interested in learning how to work with **APIs** to pull real-world data into projects, making them dynamic and interactive.
#
# - I want to deepen my understanding of **data structures and algorithms**, so I can write more efficient programs and solve complex problems.
#
# - Ultimately, I want to build projects that not only function well but also have a thoughtful, user-friendly design.
#
#
# By focusing on these areas, I hope to combine creativity and logic to create more advanced and impactful projects in the future.

# %% [markdown]
# # Analytics Summary
# - **Commits:** 108
# - **Pull Requests:** 2
# - **Issues:** 10
# - **Contributions:** 16

# %% [markdown]
# # 📊 AP CSP Multiple Choice Review
# Overall Performance: 45/66 (68.2%)
#
# Q9 – Iterative Development Benefits
# Your Answer: A | Correct: D
# Key Concept: Purpose of incremental development process
# * Iterative development helps identify errors as new code is added to working programs
# * Why I got it wrong: Thought it could solve unsolvable problems, but no algorithm can solve truly unsolvable problems
#
# Q12 – Social Media Linear Growth Projection
# Your Answer: C (31.8) | Correct: B (31.2)
# Key Concept: Calculating future values from constant rate patterns
# * Users grow by 0.5 million/year, so year 12 = 30.2 + 0.5 + 0.5 = 31.2
# * Why I got it wrong: Used 31.8 which is actually year 13's value, added one too many increments
#
# Q14 – Comparing Loop Display Output
# Your Answer: D | Correct: C
# Key Concept: When DISPLAY happens relative to variable changes matters
# * Both loops run 10 times, but Program B displays after incrementing (values are +1)
# * Why I got it wrong: Didn't trace carefully, assumed different loop counts instead of checking display timing
#
# Q16 – Licensed Music Download Consequences
# Your Answer: C | Correct: D
# Key Concept: Legal vs common consequences of downloads
# * Buying from licensed seller is legal, doesn't violate DMCA
# * Why I got it wrong: Thought recommendations were unlikely, but that's actually very common - DMCA violation is what's LEAST likely
#
# Q24 – Byte Pair Encoding Type
# Your Answer: B (lossy) | Correct: C (lossless)
# Key Concept: Whether original data can be recovered
# * Mapping list allows reversing the encoding completely
# * Why I got it wrong: Saw compression replacing characters and assumed data loss, forgot about the saved mapping
#
# Q26 – Robot Conditional Navigation
# Your Answer: (wrong code) | Correct: B (rotate right when open)
# Key Concept: Following conditional movement patterns on grid
# * Robot checks if right is open, rotates, continues forward
# * Why I got it wrong: Didn't trace the full path step-by-step through the grid
#
# Q27 – Loop Termination Fix
# Your Answer: Between lines 6-7 | Correct: Between lines 9-10
# Key Concept: Where to place exit condition in loop
# * Must update after checking if guess is correct, not before
# * Why I got it wrong: Placed it too early - would exit even with wrong guesses
#
# Q30 – Procedure Call Runtime
# Your Answer: 1 hour | Correct: 5 hours
# Key Concept: Counting all procedure calls including setup
# * GetViewers() runs once before loop + 4 times in loop = 5 total
# * Why I got it wrong: Only counted the loop, forgot the initial call before the loop starts
#
# Q31 – Multiple Robot Solutions
# Your Answer: Only I works | Correct: Both work
# Key Concept: Different algorithms can solve the same problem
# * Program I uses repeated pattern, Program II goes to corners first
# * Why I got it wrong: Didn't fully trace Program II, assumed it failed without checking
#
# Q33 – Flowchart to Boolean Expression
# Your Answer: (wrong expression) | Correct: (bedrooms ≥ 2) AND (price ≤ 1000)
# Key Concept: Converting decision trees to single boolean statements
# * Both conditions must be true for display banner
# * Why I got it wrong: Confused the AND/OR logic from the flowchart structure
#
# Q41 – Grade Replacement with MAX
# Your Answer: Replace final with max | Correct: Replace midterm with max
# Key Concept: Which score gets replaced in the policy
# * If final > midterm, final replaces midterm in calculation
# * Why I got it wrong: Read it backwards - replaced the wrong score
#
# Q42 – IPv6 vs IPv4 Address Space
# Your Answer: A (4× more) | Correct: D (2^96× more)
# Key Concept: Exponential growth with bit increases
# * 2^128 / 2^32 = 2^96, not just 4 times larger
# * Why I got it wrong: Did simple division (128/32=4) instead of understanding exponential difference
#
# Q43 – Algorithm Efficiency Classification
# Your Answer: B (unreasonable) | Correct: A (reasonable)
# Key Concept: Polynomial vs exponential runtime
# * n² steps is polynomial = reasonable time
# * Why I got it wrong: Saw large numbers and assumed slow, didn't recognize polynomial pattern
#
# Q45 – NAND Gate Boolean Expression
# Your Answer: A ((NOT A) AND (NOT B)) | Correct: D (NOT (A AND B))
# Key Concept: NAND is the opposite of AND
# * False only when both true = NOT(A AND B)
# * Why I got it wrong: Applied NOT to each input separately instead of to the AND result
#
# Q47 – Decrypting Public Key Messages
# Your Answer: B (sender's private) | Correct: D (recipient's private)
# Key Concept: Public/private key pair usage
# * Encrypt with public key, decrypt with matching private key
# * Why I got it wrong: Thought sender was involved in decryption, forgot it's recipient's key pair
#
# Q52 – Palindrome Algorithm Order
# Your Answer: B (II only) | Correct: C (II and III)
# Key Concept: Step dependencies in algorithms
# * Must identify palindromes before shortening, but sorting can happen anywhere
# * Why I got it wrong: Didn't realize sorting first still works since palindrome check comes before shorten
#
# Q54 – Generalizing Procedures
# Your Answer: B (Power(n) = n²) | Correct: D (Power(n,m) = n^m)
# Key Concept: Creating flexible procedures from specific ones
# * Need two parameters to generalize all power operations
# * Why I got it wrong: Made it specific to squaring instead of fully generalizing with exponent parameter
#
# Q55 – Boolean Expression Bug
# Your Answer: A (returns true for "y") | Correct: B (always true)
# Key Concept: OR conditions with single variable
# * (response = "y") OR (response = "n") is always true
# * Why I got it wrong: Didn't realize the logic flaw - one of those conditions must be true
#
# Q63 – Debugging Prime Counter (SELECT TWO)
# Your Answer: D only | Correct: B AND D
# Key Concept: Finding all bugs in flawed code
# * Line 4 resets count every iteration, Line 9 increments for all numbers
# * Why I got it wrong: Found one bug but didn't look for additional errors
#
# Q64 – Cloud Computing Impact (SELECT TWO)
# Your Answer: A | Correct: B AND C
# Key Concept: Multiple effects of cloud technology
# * Enhances collaboration, introduces security risks
# * Why I got it wrong: Picked redundancy elimination which is wrong - cloud needs redundancy for reliability
#
# Q65 – Multiply Bug Conditions (SELECT TWO)
# Your Answer: C only | Correct: B AND D
# Key Concept: Testing with negative values
# * Loop fails when y is negative (counter never reaches negative target)
# * Why I got it wrong: Tested x negative with y positive (which works), didn't test y negative cases
#
# ---
#
# ## My Common Mistakes
#
# **Missing "SELECT TWO" (3 times)**: Q63, Q64, Q65
# * Stop at first correct answer without finding the second
# * Fix: Circle "TWO" in the question immediately
#
# **Not Tracing Fully (4 times)**: Q14, Q26, Q31, Q52
# * Make assumptions instead of step-by-step execution
# * Fix: Use scratch paper to trace every step
#
# **Boolean Logic Errors (4 times)**: Q33, Q45, Q55, Q65
# * Confuse AND/OR, don't see impossible conditions
# * Fix: Write truth table for anything complex
#
# **Math/Exponents (2 times)**: Q12, Q42
# * Arithmetic mistakes, forget exponential rules
# * Fix: Write calculations out, don't do mental math
#
# **Reading Too Fast (3 times)**: Q16, Q41, Q47
# * Miss key words like "LEAST likely", mix up sender/recipient
# * Fix: Highlight critical words before answering
#
# **Incomplete Counting (2 times)**: Q30, Q43
# * Forget initial calls, misidentify complexity classes
# * Fix: Count everything explicitly on paper
#
# ---
#
# ## Study Plan
#
# 1. **Practice tracing** - 10 algorithm problems traced on paper
# 2. **Truth tables drill** - Create tables for 5 complex boolean expressions
# 3. **Read questions twice** - Mark all "TWO", "LEAST", "NOT" keywords
# 4. **Test negative numbers** - Always try negative/zero/boundary cases
# 5. **Review compression** - Lossy vs lossless, when data is recoverable
# 6. **Binary/exponents** - Review powers of 2, exponential vs linear growth

# %% [markdown]
# ### Final Thoughts
# - I really enjoyed the teamwork in this class and how everyone collaborated on projects.
#
# - I’m thankful for the support and guidance from the TAs throughout the course.
#
# - The Night at the Museum project was a favorite of mine because it allowed me to be creative and apply what I learned.
#
# - I feel that I grew a lot in this class, not just in coding skills, but also in problem-solving and thinking algorithmically.
#
# - Overall, this class was challenging but rewarding, and I’m proud of the progress I made.
