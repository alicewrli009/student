# %% [raw]
# ---
# title: Alice's Tri 1 Retrospective
# comments: true
# layout: post
# permalink: /retrospectiveblog
# author: Alice Li
# ---

# %% [markdown]
# # Looking Back and Moving Forward

# %% [markdown]
# <html lang="en">
# <head>
#     <meta charset="UTF-8">
#     <meta name="viewport" content="width=device-width, initial-scale=1.0">
#     <title>My Computer Science Journey - 2025 Tri 1 Retrospective</title>
#     <style>
#         * {
#             margin: 0;
#             padding: 0;
#             box-sizing: border-box;
#         }
#
#         body {
#             font-family: 'Segoe UI', Tahoma, Geneva, Verdana, sans-serif;
#             background: linear-gradient(135deg, #0f0f0f 0%, #1a1a2e 100%);
#             min-height: 100vh;
#             padding: 20px;
#         }
#
#         .container {
#             max-width: 1000px;
#             margin: 0 auto;
#             background: #1a1a1a;
#             border-radius: 20px;
#             box-shadow: 0 20px 60px rgba(0, 0, 0, 0.8);
#             overflow: hidden;
#             animation: slideIn 0.6s ease-out;
#             border: 1px solid #333;
#             margin-bottom: 40px;
#         }
#
#         @keyframes slideIn {
#             from {
#                 opacity: 0;
#                 transform: translateY(30px);
#             }
#             to {
#                 opacity: 1;
#                 transform: translateY(0);
#             }
#         }
#
#         .header {
#             background: linear-gradient(135deg, #6366f1 0%, #8b5cf6 100%);
#             color: white;
#             padding: 50px 40px;
#             text-align: center;
#         }
#
#         .header h1 {
#             font-size: 2.8em;
#             margin-bottom: 15px;
#             text-shadow: 2px 2px 4px rgba(0, 0, 0, 0.5);
#         }
#
#         .header p {
#             font-size: 1.3em;
#             opacity: 0.95;
#         }
#
#         .content {
#             padding: 40px;
#         }
#
#         .section {
#             margin-bottom: 40px;
#             padding: 30px;
#             background: #252525;
#             border-radius: 15px;
#             border-left: 5px solid #6366f1;
#             transition: transform 0.3s ease, box-shadow 0.3s ease;
#         }
#
#         .section:hover {
#             transform: translateX(5px);
#             box-shadow: 0 8px 20px rgba(99, 102, 241, 0.4);
#         }
#
#         .section h2 {
#             color: #8b5cf6;
#             margin-bottom: 20px;
#             font-size: 2em;
#         }
#
#         .section h3 {
#             color: #a78bfa;
#             margin: 25px 0 15px 0;
#             font-size: 1.5em;
#         }
#
#         .section p, .section li {
#             color: #e0e0e0;
#             line-height: 1.8;
#             font-size: 1.1em;
#             margin-bottom: 15px;
#         }
#
#         .skills-grid {
#             display: grid;
#             grid-template-columns: repeat(auto-fit, minmax(280px, 1fr));
#             gap: 20px;
#             margin-top: 25px;
#         }
#
#         .skill-card {
#             background: #2a2a2a;
#             padding: 25px;
#             border-radius: 12px;
#             box-shadow: 0 4px 10px rgba(0, 0, 0, 0.5);
#             transition: all 0.3s ease;
#             cursor: pointer;
#             border: 1px solid #333;
#         }
#
#         .skill-card:hover {
#             background: linear-gradient(135deg, #6366f1 0%, #8b5cf6 100%);
#             color: white;
#             transform: translateY(-5px);
#             box-shadow: 0 8px 20px rgba(99, 102, 241, 0.6);
#             border-color: #8b5cf6;
#         }
#
#         .skill-card h3 {
#             color: #8b5cf6;
#             margin: 0 0 12px 0;
#             font-size: 1.3em;
#             transition: color 0.3s ease;
#         }
#
#         .skill-card:hover h3 {
#             color: white;
#         }
#
#         .skill-card p {
#             font-size: 1em;
#             margin: 0;
#             color: #b0b0b0;
#             transition: color 0.3s ease;
#         }
#
#         .skill-card:hover p {
#             color: rgba(255, 255, 255, 0.95);
#         }
#
#         .collab-list, .sprint-list {
#             list-style: none;
#             margin-top: 20px;
#         }
#
#         .collab-list li, .sprint-list li {
#             padding: 15px 15px 15px 45px;
#             margin-bottom: 12px;
#             background: #2a2a2a;
#             border-radius: 10px;
#             color: #e0e0e0;
#             font-size: 1.05em;
#             box-shadow: 0 2px 8px rgba(0, 0, 0, 0.5);
#             transition: all 0.3s ease;
#             border: 1px solid #333;
#             position: relative;
#         }
#
#         .collab-list li:hover, .sprint-list li:hover {
#             background: linear-gradient(135deg, #6366f1 0%, #8b5cf6 100%);
#             color: white;
#             transform: translateX(10px);
#             border-color: #8b5cf6;
#         }
#
#         .collab-list li::before {
#             content: "✓";
#             position: absolute;
#             left: 15px;
#             color: #8b5cf6;
#             font-weight: bold;
#             font-size: 1.4em;
#         }
#
#         .sprint-list li::before {
#             content: "•";
#             position: absolute;
#             left: 18px;
#             color: #8b5cf6;
#             font-weight: bold;
#             font-size: 1.6em;
#         }
#
#         .collab-list li:hover::before, .sprint-list li:hover::before {
#             color: white;
#         }
#
#         .sprint-box {
#             background: #2a2a2a;
#             padding: 30px;
#             border-radius: 12px;
#             margin-bottom: 30px;
#             border: 2px solid #333;
#             transition: all 0.3s ease;
#         }
#
#         .sprint-box:hover {
#             border-color: #8b5cf6;
#             box-shadow: 0 8px 20px rgba(139, 92, 246, 0.3);
#         }
#
#         .sprint-box h3 {
#             color: #8b5cf6;
#             font-size: 1.8em;
#             margin-bottom: 15px;
#         }
#
#         .big-idea-grid {
#             display: grid;
#             grid-template-columns: repeat(auto-fit, minmax(300px, 1fr));
#             gap: 20px;
#             margin-top: 25px;
#         }
#
#         .big-idea-card {
#             background: #2a2a2a;
#             padding: 20px;
#             border-radius: 10px;
#             border-left: 4px solid #6366f1;
#             transition: all 0.3s ease;
#         }
#
#         .big-idea-card:hover {
#             background: #333;
#             border-left-color: #8b5cf6;
#             transform: translateX(5px);
#         }
#
#         .big-idea-card h3 {
#             color: #a78bfa;
#             font-size: 1.3em;
#             margin: 0 0 12px 0;
#         }
#
#         .big-idea-card ul {
#             list-style: none;
#             padding-left: 0;
#         }
#
#         .big-idea-card li {
#             color: #d0d0d0;
#             font-size: 0.95em;
#             margin-bottom: 8px;
#             padding-left: 20px;
#             position: relative;
#         }
#
#         .big-idea-card li::before {
#             content: "→";
#             position: absolute;
#             left: 0;
#             color: #8b5cf6;
#         }
#
#         .slideshow-container {
#             max-width: 500px;
#             margin: 30px auto;
#             text-align: center;
#             background: #2a2a2a;
#             padding: 25px;
#             border-radius: 15px;
#             border: 2px solid #333;
#         }
#
#         .slideshow-container img {
#             width: 100%;
#             border-radius: 12px;
#             box-shadow: 0 4px 15px rgba(0, 0, 0, 0.5);
#         }
#
#         .slideshow-buttons {
#             margin-top: 20px;
#         }
#
#         .slideshow-buttons button {
#             background: linear-gradient(135deg, #6366f1 0%, #8b5cf6 100%);
#             color: white;
#             border: none;
#             padding: 12px 25px;
#             margin: 0 8px;
#             border-radius: 8px;
#             font-size: 1em;
#             cursor: pointer;
#             transition: all 0.3s ease;
#         }
#
#         .slideshow-buttons button:hover {
#             transform: translateY(-2px);
#             box-shadow: 0 6px 15px rgba(99, 102, 241, 0.5);
#         }
#
#         .analytics-grid {
#             display: grid;
#             grid-template-columns: repeat(auto-fit, minmax(200px, 1fr));
#             gap: 20px;
#             margin-top: 25px;
#         }
#
#         .analytics-card {
#             background: linear-gradient(135deg, #2a2a2a 0%, #333 100%);
#             padding: 25px;
#             border-radius: 12px;
#             text-align: center;
#             border: 2px solid #444;
#             transition: all 0.3s ease;
#         }
#
#         .analytics-card:hover {
#             border-color: #8b5cf6;
#             transform: scale(1.05);
#             box-shadow: 0 8px 20px rgba(139, 92, 246, 0.4);
#         }
#
#         .analytics-card h3 {
#             color: #8b5cf6;
#             font-size: 2.5em;
#             margin: 0 0 10px 0;
#         }
#
#         .analytics-card p {
#             color: #b0b0b0;
#             font-size: 1.1em;
#             margin: 0;
#         }
#
#         .mcq-stats {
#             background: #2a2a2a;
#             padding: 25px;
#             border-radius: 12px;
#             margin-bottom: 25px;
#             text-align: center;
#             border: 2px solid #6366f1;
#         }
#
#         .mcq-stats h3 {
#             color: #8b5cf6;
#             font-size: 2em;
#             margin-bottom: 10px;
#         }
#
#         .mcq-stats p {
#             color: #e0e0e0;
#             font-size: 1.3em;
#         }
#
#         .mistake-category {
#             background: #2a2a2a;
#             padding: 20px;
#             border-radius: 10px;
#             margin-bottom: 15px;
#             border-left: 4px solid #ef4444;
#         }
#
#         .mistake-category h4 {
#             color: #fca5a5;
#             margin-bottom: 10px;
#             font-size: 1.2em;
#         }
#
#         .conclusion {
#             background: linear-gradient(135deg, #6366f1 0%, #8b5cf6 100%);
#             color: white;
#             padding: 35px;
#             border-radius: 15px;
#             text-align: center;
#             font-size: 1.2em;
#             line-height: 1.9;
#             box-shadow: 0 8px 20px rgba(99, 102, 241, 0.6);
#             margin-top: 40px;
#         }
#
#         @media (max-width: 768px) {
#             .header h1 {
#                 font-size: 2em;
#             }
#
#             .skills-grid, .big-idea-grid, .analytics-grid {
#                 grid-template-columns: 1fr;
#             }
#         }
#     </style>
# </head>
# <body>
#     <div class="container">
#         <div class="header">
#             <h1>💻 My Computer Science Journey</h1>
#             <p>2025 Retrospective & Reflection</p>
#         </div>
#
#         <div class="content">
#             <!-- Comparing Myself Section -->
#             <div class="section">
#                 <h2>🧭 Comparing Myself to the Beginning of the Year</h2>
#                 <p>At the start of the year, I didn't really understand how code worked. I just followed the steps without knowing <strong>why</strong> things happened.</p>
#                 <p>Now, after learning <strong>Big Idea 3: Algorithms and Programming</strong>, I can confidently explain and apply key coding concepts:</p>
#
#                 <div class="skills-grid">
#                     <div class="skill-card">
#                         <h3>Variables</h3>
#                         <p>I learned how to store, update, and use data efficiently in programs</p>
#                     </div>
#
#                     <div class="skill-card">
#                         <h3>Functions / Procedures</h3>
#                         <p>I can group code into reusable blocks that make programs cleaner and easier to manage</p>
#                     </div>
#
#                     <div class="skill-card">
#                         <h3>Parameters</h3>
#                         <p>I understand how parameters make procedures flexible so they can handle different inputs</p>
#                     </div>
#
#                     <div class="skill-card">
#                         <h3>Loops & Conditionals</h3>
#                         <p>I know how to use loops to repeat actions and conditionals to make decisions in an algorithm</p>
#                     </div>
#
#                     <div class="skill-card">
#                         <h3>Calling Procedures</h3>
#                         <p>I've practiced connecting one function's output to another's input to build more complex programs</p>
#                     </div>
#
#                     <div class="skill-card">
#                         <h3>Algorithm Design</h3>
#                         <p>I can break big problems into smaller parts and write clear, step-by-step instructions for solving them</p>
#                     </div>
#                 </div>
#
#                 <h3 style="margin-top: 35px;">🤝 Collaboration Growth</h3>
#                 <p>I've also grown in collaboration this year:</p>
#                 <ul class="collab-list">
#                     <li>Learned to explain my reasoning and communicate clearly when coding with others</li>
#                     <li>Worked through debugging and brainstorming as a team</li>
#                     <li>Divided tasks and helped others understand their parts of the project</li>
#                 </ul>
#
#                 <div class="conclusion" style="margin-top: 30px;">
#                     <strong>Overall:</strong> I've gone from just <em>following code</em> to really <em>understanding and creating</em> it. I feel much more confident and creative as a problem solver! 🚀
#                 </div>
#             </div>
#
#             <!-- Three Sprints Section -->
#             <div class="section">
#                 <h2>🏁 Remembering the Three Sprints</h2>
#                 <p>Throughout this semester, each sprint helped me grow as a coder, problem solver, and designer. Here's what I learned from each one:</p>
#
#                 <div class="sprint-box">
#                     <h3>🧰 Tools Sprint</h3>
#                     <p>This sprint focused on learning the essential tools that real developers use every day. I learned how to set up my workspace, organize files, and share projects online.</p>
#                     <ul class="sprint-list">
#                         <li>Learned to use <strong>VS Code</strong> for writing, editing, and previewing my code efficiently</li>
#                         <li>Practiced <strong>HTML</strong> for structure and <strong>CSS</strong> for styling web pages</li>
#                         <li>Gained experience with <strong>GitHub</strong>, learning how to upload, version control, and publish projects</li>
#                         <li>Created and deployed my first webpage — it was exciting to see my code live on the internet!</li>
#                         <li>Learned the importance of file paths, folder organization, and commenting my code for clarity</li>
#                     </ul>
#                     <p style="margin-top: 15px; color: #a78bfa; font-style: italic;">This sprint built the foundation for everything else — it helped me feel like an actual web developer.</p>
#                 </div>
#
#                 <div class="sprint-box">
#                     <h3>💡 Fundamentals of JavaScript/Python Sprint</h3>
#                     <p>This sprint was where I really started to <strong>think like a programmer</strong>. I began to understand how logic drives everything behind the scenes.</p>
#                     <ul class="sprint-list">
#                         <li>Practiced <strong>writing functions</strong> to make code modular and reusable</li>
#                         <li>Used <strong>variables</strong> to store and manipulate data in both JavaScript and Python</li>
#                         <li>Worked with <strong>loops</strong> and <strong>conditionals</strong> to automate processes and make programs dynamic</li>
#                         <li>Learned about <strong>input and output</strong>, letting users interact with my code</li>
#                         <li>Debugged errors by testing step-by-step and reading console messages carefully</li>
#                         <li>Applied <strong>problem decomposition</strong> — breaking complex problems into smaller, solvable parts</li>
#                     </ul>
#                     <p style="margin-top: 15px; color: #a78bfa; font-style: italic;">This sprint helped me connect the logic I was writing to the actual outcomes I could see and interact with.</p>
#                 </div>
#
#                 <div class="sprint-box">
#                     <h3>🌴 West Coast Travel Quest</h3>
#                     <p>This was my favorite sprint because it combined creativity, storytelling, and coding skills all at once! I got to build a travel website that reflected my interests while using more advanced programming techniques.</p>
#                     <ul class="sprint-list">
#                         <li>Designed interactive <strong>travel pages</strong> using HTML, CSS, and JavaScript</li>
#                         <li>Added <strong>animations and transitions</strong> to make the website feel alive and engaging</li>
#                         <li>Learned how to <strong>organize code</strong> with reusable components and clean formatting</li>
#                         <li>Practiced <strong>testing and debugging</strong> to make sure everything ran smoothly</li>
#                         <li>Used design thinking to consider the <strong>user experience (UI)</strong> — how others would navigate and enjoy the site</li>
#                         <li>Showed me how front-end coding works</li>
#                         <li>Incorporated images, hover effects, and buttons for a more dynamic visual story</li>
#                     </ul>
#                     <p style="margin-top: 15px; color: #a78bfa; font-style: italic;">This sprint made me realize that programming isn't just about logic — it's also a creative form of expression. Even though there were struggles, we persevered and it all came together at the end.</p>
#                 </div>
#
#                 <p style="font-size: 1.15em; color: #c4b5fd; margin-top: 25px;"><strong>Each sprint built on the last, helping me grow from learning basic syntax to designing interactive, meaningful projects.</strong></p>
#             </div>
#
#             <!-- Big Idea 3 Reflection -->
#             <div class="section">
#                 <h2>📚 Big Idea 3 Reflection</h2>
#                 <p>A deep dive into the key concepts I mastered this year:</p>
#
#                 <div class="big-idea-grid">
#                     <div class="big-idea-card">
#                         <h3>3.1 – Variables</h3>
#                         <ul>
#                             <li>Variables store information for later use in a program</li>
#                             <li>I learned how to assign values correctly</li>
#                             <li>Using clear, descriptive names makes code easier to read and maintain</li>
#                         </ul>
#                     </div>
#
#                     <div class="big-idea-card">
#                         <h3>3.2 – Lists and Strings</h3>
#                         <ul>
#                             <li>Lists help manage complexity by storing many related items in one variable</li>
#                             <li>They can grow or shrink as needed and allow the same computation on all elements</li>
#                             <li>Strings and lists are both ordered sequences</li>
#                         </ul>
#                     </div>
#
#                     <div class="big-idea-card">
#                         <h3>3.3 – Algorithms and Teaching</h3>
#                         <ul>
#                             <li>I created JavaScript and Python homework</li>
#                             <li>Learned about learning objectives and algorithms</li>
#                             <li>Taught others how algorithms work</li>
#                         </ul>
#                     </div>
#
#                     <div class="big-idea-card">
#                         <h3>3.4 – Strings</h3>
#                         <ul>
#                             <li>Strings are sequences of characters inside quotes used to store text</li>
#                             <li>I learned to define strings in both Python and JavaScript</li>
#                             <li>Practiced using operations like upper, lower, slicing, and concatenation</li>
#                             <li>Learned how to create multiline strings</li>
#                         </ul>
#                     </div>
#
#                     <div class="big-idea-card">
#                         <h3>3.5 – Boolean Expressions</h3>
#                         <ul>
#                             <li>Booleans help programs make decisions with True or False values</li>
#                             <li>Relational operators compare values, and modulus checks remainders</li>
#                             <li>Logical operators like not, and, or combine or flip conditions</li>
#                         </ul>
#                     </div>
#
#                     <div class="big-idea-card">
#                         <h3>3.6 – Conditionals</h3>
#                         <ul>
#                             <li>Conditionals let programs make decisions based on conditions</li>
#                             <li>I used if, elif/else if, and else to control code flow</li>
#                             <li>Learned to use comparison and logical operators with Booleans</li>
#                         </ul>
#                     </div>
#
#                     <div class="big-idea-card">
#                         <h3>3.7 – Nested Conditionals</h3>
#                         <ul>
#                             <li>Nested conditionals are if statements inside other if statements</li>
#                             <li>They help handle multiple related decisions in order</li>
#                             <li>Useful for complex logic like age checks or game conditions</li>
#                         </ul>
#                     </div>
#
#                     <div class="big-idea-card">
#                         <h3>3.8 – Iteration</h3>
#                         <ul>
#                             <li>Iterations repeat code using loops</li>
#                             <li>For loops go through sequences, while loops repeat while a condition is True</li>
#                             <li>Loops can be nested or indexed with enumerate()</li>
#                         </ul>
#                     </div>
#
#                     <div class="big-idea-card">
#                         <h3>3.9 – Developing Algorithms</h3>
#                         <ul>
#                             <li>Algorithms are step-by-step instructions to solve problems</li>
#                             <li>Clear algorithms make code easier to understand, test, and debug</li>
#                             <li>Efficiency matters when designing algorithms</li>
#                         </ul>
#                     </div>
#
#                     <div class="big-idea-card">
#                         <h3>3.10 – Lists</h3>
#                         <ul>
#                             <li>Lists organize and process multiple pieces of data</li>
#                             <li>I practiced adding, removing, and looping through list elements</li>
#                             <li>Lists make programs more flexible and dynamic</li>
#                         </ul>
#                     </div>
#
#                     <div class="big-idea-card">
#                         <h3>3.12 – Calling Procedures</h3>
#                         <ul>
#                             <li>Calling procedures helps reuse code efficiently</li>
#                             <li>I learned to pass arguments into functions</li>
#                             <li>Functions simplify and organize complex programs</li>
#                         </ul>
#                     </div>
#
#                     <div class="big-idea-card">
#                         <h3>3.13 – Developing Procedures</h3>
#                         <ul>
#                             <li>I learned how to define my own procedures</li>
#                             <li>Functions make programs cleaner and more organized</li>
#                             <li>Reusable code reduces errors and improves structure</li>
#                         </ul>
#                     </div>
#
#                     <div class="big-idea-card">
#                         <h3>3.15 – Random Values</h3>
#                         <ul>
#                             <li>Random values add variety and unpredictability to programs</li>
#                             <li>Useful in games, simulations, and testing</li>
#                             <li>I learned how to generate and use random numbers in code</li>
#                         </ul>
#                     </div>
#
#                     <div class="big-idea-card">
#                         <h3>3.17 – Algorithmic Efficiency</h3>
#                         <ul>
#                             <li>Algorithmic efficiency measures how fast and resourceful a program is</li>
#                             <li>Efficient algorithms save time and improve performance</li>
#                             <li>I learned to compare different approaches to find the best one</li>
#                         </ul>
#                     </div>
#                 </div>
#             </div>
#
#             <!-- Night at the Museum -->
#             <div class="section">
#                 <h2>🎨 Night at the Museum</h2>
#                 <p>The Night at the Museum project was a highlight of the year. It gave me the opportunity to showcase what I learned and share it with others in a creative, interactive way.</p>
#
#                 <div class="slideshow-container">
#                     <img id="slide" src="https://via.placeholder.com/500x350/6366f1/ffffff?text=Night+at+the+Museum" alt="Night at the Museum">
#                     <div class="slideshow-buttons">
#                         <button onclick="prevImage()">⬅️ Previous</button>
#                         <button onclick="nextImage()">Next ➡️</button>
#                     </div>
#                 </div>
#
#                 <p style="text-align: center; font-style: italic; color: #a78bfa;">The Cool Collaborators at Night at the Museum!</p>
#             </div>
#
#             <!-- Next Steps -->
#             <div class="section">
#                 <h2>🚀 Next Steps: Travel Module Project</h2>
#                 <p>For my next project, I want to continue building my <strong>Travel Module</strong> and make it more interactive and dynamic.</p>
#                 <ul class="sprint-list">
#                     <li>I plan to add <strong>animations and smooth transitions</strong> between destinations to make the experience feel like an actual journey</li>
#                     <li>I want to include a <strong>navigation bar or map feature</strong> that lets users explore different locations in any order, creating a more immersive experience</li>
#                     <li>If time allows, I'd love to connect it to <strong>real-world data using an API</strong>, such as live weather updates, maps, or travel images</li>
#                     <li>I'll focus on improving <strong>UI design</strong> and <strong>user experience</strong> by keeping layouts consistent, readable, and visually appealing</li>
#                     <li>I also want to organize my code better with <strong>functions and reusable components</strong>, so it's easier to maintain and expand later</li>
#                 </ul>
#                 <p style="margin-top: 20px; font-size: 1.15em; color: #c4b5fd;">Overall, my goal is to take what I learned from the West Coast Travel Quest and turn it into a more advanced project that combines creativity, interactivity, and real-world data.</p>
#             </div>
#
#             <!-- What's Next in CS -->
#             <div class="section">
#                 <h2>🔮 What I Want to Learn Next in Computer Science</h2>
#                 <p>Looking ahead, I want to continue building on the skills I've learned this year and explore new areas of computer science.</p>
#                 <ul class="sprint-list">
#                     <li>I want to learn more about <strong>how front-end and back-end systems work together</strong>, including how data moves between a website and a server</li>
#                     <li>I'm interested in learning how to work with <strong>APIs</strong> to pull real-world data into projects, making them dynamic and interactive</li>
#                     <li>I want to deepen my understanding of <strong>data structures and algorithms</strong>, so I can write more efficient programs and solve complex problems</li>
#                     <li>Ultimately, I want to build projects that not only function well but also have a thoughtful, user-friendly design</li>
#                 </ul>
#                 <p style="margin-top: 20px; font-size: 1.15em; color: #c4b5fd;">By focusing on these areas, I hope to combine creativity and logic to create more advanced and impactful projects in the future.</p>
#             </div>
#
#             <!-- Analytics -->
#             <div class="section">
#                 <h2>📊 Analytics Summary</h2>
#                 <p>Here's a look at my contributions and activity throughout the year:</p>
#
#                 <div class="analytics-grid">
#                     <div class="analytics-card">
#                         <h3>108</h3>
#                         <p>Commits</p>
#                     </div>
#                     <div class="analytics-card">
#                         <h3>2</h3>
#                         <p>Pull Requests</p>
#                     </div>
#                     <div class="analytics-card">
#                         <h3>10</h3>
#                         <p>Issues</p>
#                     </div>
#                     <div class="analytics-card">
#                         <h3>16</h3>
#                         <p>Contributions</p>
#                     </div>
#                 </div>
#             </div>
#
#             <!-- MCQ Review -->
#             <div class="section">
#                 <h2>📝 AP CSP Multiple Choice Review</h2>
#
#                 <div class="mcq-stats">
#                     <h3>Overall Performance</h3>
#                     <p><strong>45/66</strong> (68.2%)</p>
#                 </div>
#
#                 <h3>Detailed Question-by-Question Analysis</h3>
#                 <p style="margin-bottom: 25px;">Here are all 21 questions I got wrong, with explanations of the correct answers and why I made each mistake:</p>
#
#                 <div class="mistake-category">
#                     <h4>Q9 – Iterative Development Benefits</h4>
#                     <p><strong>Your Answer:</strong> A | <strong>Correct:</strong> D</p>
#                     <p><strong>Key Concept:</strong> Purpose of incremental development process</p>
#                     <ul style="list-style: disc; margin-left: 25px; margin-top: 10px;">
#                         <li>Iterative development helps identify errors as new code is added to working programs</li>
#                         <li><strong>Why I got it wrong:</strong> Thought it could solve unsolvable problems, but no algorithm can solve truly unsolvable problems</li>
#                     </ul>
#                 </div>
#
#                 <div class="mistake-category">
#                     <h4>Q12 – Social Media Linear Growth Projection</h4>
#                     <p><strong>Your Answer:</strong> C (31.8) | <strong>Correct:</strong> B (31.2)</p>
#                     <p><strong>Key Concept:</strong> Calculating future values from constant rate patterns</p>
#                     <ul style="list-style: disc; margin-left: 25px; margin-top: 10px;">
#                         <li>Users grow by 0.5 million/year, so year 12 = 30.2 + 0.5 + 0.5 = 31.2</li>
#                         <li><strong>Why I got it wrong:</strong> Used 31.8 which is actually year 13's value, added one too many increments</li>
#                     </ul>
#                 </div>
#
#                 <div class="mistake-category">
#                     <h4>Q14 – Comparing Loop Display Output</h4>
#                     <p><strong>Your Answer:</strong> D | <strong>Correct:</strong> C</p>
#                     <p><strong>Key Concept:</strong> When DISPLAY happens relative to variable changes matters</p>
#                     <ul style="list-style: disc; margin-left: 25px; margin-top: 10px;">
#                         <li>Both loops run 10 times, but Program B displays after incrementing (values are +1)</li>
#                         <li><strong>Why I got it wrong:</strong> Didn't trace carefully, assumed different loop counts instead of checking display timing</li>
#                     </ul>
#                 </div>
#
#                 <div class="mistake-category">
#                     <h4>Q16 – Licensed Music Download Consequences</h4>
#                     <p><strong>Your Answer:</strong> C | <strong>Correct:</strong> D</p>
#                     <p><strong>Key Concept:</strong> Legal vs common consequences of downloads</p>
#                     <ul style="list-style: disc; margin-left: 25px; margin-top: 10px;">
#                         <li>Buying from licensed seller is legal, doesn't violate DMCA</li>
#                         <li><strong>Why I got it wrong:</strong> Thought recommendations were unlikely, but that's actually very common - DMCA violation is what's LEAST likely</li>
#                     </ul>
#                 </div>
#
#                 <div class="mistake-category">
#                     <h4>Q24 – Byte Pair Encoding Type</h4>
#                     <p><strong>Your Answer:</strong> B (lossy) | <strong>Correct:</strong> C (lossless)</p>
#                     <p><strong>Key Concept:</strong> Whether original data can be recovered</p>
#                     <ul style="list-style: disc; margin-left: 25px; margin-top: 10px;">
#                         <li>Mapping list allows reversing the encoding completely</li>
#                         <li><strong>Why I got it wrong:</strong> Saw compression replacing characters and assumed data loss, forgot about the saved mapping</li>
#                     </ul>
#                 </div>
#
#                 <div class="mistake-category">
#                     <h4>Q26 – Robot Conditional Navigation</h4>
#                     <p><strong>Your Answer:</strong> (wrong code) | <strong>Correct:</strong> B (rotate right when open)</p>
#                     <p><strong>Key Concept:</strong> Following conditional movement patterns on grid</p>
#                     <ul style="list-style: disc; margin-left: 25px; margin-top: 10px;">
#                         <li>Robot checks if right is open, rotates, continues forward</li>
#                         <li><strong>Why I got it wrong:</strong> Didn't trace the full path step-by-step through the grid</li>
#                     </ul>
#                 </div>
#
#                 <div class="mistake-category">
#                     <h4>Q27 – Loop Termination Fix</h4>
#                     <p><strong>Your Answer:</strong> Between lines 6-7 | <strong>Correct:</strong> Between lines 9-10</p>
#                     <p><strong>Key Concept:</strong> Where to place exit condition in loop</p>
#                     <ul style="list-style: disc; margin-left: 25px; margin-top: 10px;">
#                         <li>Must update after checking if guess is correct, not before</li>
#                         <li><strong>Why I got it wrong:</strong> Placed it too early - would exit even with wrong guesses</li>
#                     </ul>
#                 </div>
#
#                 <div class="mistake-category">
#                     <h4>Q30 – Procedure Call Runtime</h4>
#                     <p><strong>Your Answer:</strong> 1 hour | <strong>Correct:</strong> 5 hours</p>
#                     <p><strong>Key Concept:</strong> Counting all procedure calls including setup</p>
#                     <ul style="list-style: disc; margin-left: 25px; margin-top: 10px;">
#                         <li>GetViewers() runs once before loop + 4 times in loop = 5 total</li>
#                         <li><strong>Why I got it wrong:</strong> Only counted the loop, forgot the initial call before the loop starts</li>
#                     </ul>
#                 </div>
#
#                 <div class="mistake-category">
#                     <h4>Q31 – Multiple Robot Solutions</h4>
#                     <p><strong>Your Answer:</strong> Only I works | <strong>Correct:</strong> Both work</p>
#                     <p><strong>Key Concept:</strong> Different algorithms can solve the same problem</p>
#                     <ul style="list-style: disc; margin-left: 25px; margin-top: 10px;">
#                         <li>Program I uses repeated pattern, Program II goes to corners first</li>
#                         <li><strong>Why I got it wrong:</strong> Didn't fully trace Program II, assumed it failed without checking</li>
#                     </ul>
#                 </div>
#
#                 <div class="mistake-category">
#                     <h4>Q33 – Flowchart to Boolean Expression</h4>
#                     <p><strong>Your Answer:</strong> (wrong expression) | <strong>Correct:</strong> (bedrooms ≥ 2) AND (price ≤ 1000)</p>
#                     <p><strong>Key Concept:</strong> Converting decision trees to single boolean statements</p>
#                     <ul style="list-style: disc; margin-left: 25px; margin-top: 10px;">
#                         <li>Both conditions must be true for display banner</li>
#                         <li><strong>Why I got it wrong:</strong> Confused the AND/OR logic from the flowchart structure</li>
#                     </ul>
#                 </div>
#
#                 <div class="mistake-category">
#                     <h4>Q41 – Grade Replacement with MAX</h4>
#                     <p><strong>Your Answer:</strong> Replace final with max | <strong>Correct:</strong> Replace midterm with max</p>
#                     <p><strong>Key Concept:</strong> Which score gets replaced in the policy</p>
#                     <ul style="list-style: disc; margin-left: 25px; margin-top: 10px;">
#                         <li>If final > midterm, final replaces midterm in calculation</li>
#                         <li><strong>Why I got it wrong:</strong> Read it backwards - replaced the wrong score</li>
#                     </ul>
#                 </div>
#
#                 <div class="mistake-category">
#                     <h4>Q42 – IPv6 vs IPv4 Address Space</h4>
#                     <p><strong>Your Answer:</strong> A (4× more) | <strong>Correct:</strong> D (2^96× more)</p>
#                     <p><strong>Key Concept:</strong> Exponential growth with bit increases</p>
#                     <ul style="list-style: disc; margin-left: 25px; margin-top: 10px;">
#                         <li>2^128 / 2^32 = 2^96, not just 4 times larger</li>
#                         <li><strong>Why I got it wrong:</strong> Did simple division (128/32=4) instead of understanding exponential difference</li>
#                     </ul>
#                 </div>
#
#                 <div class="mistake-category">
#                     <h4>Q43 – Algorithm Efficiency Classification</h4>
#                     <p><strong>Your Answer:</strong> B (unreasonable) | <strong>Correct:</strong> A (reasonable)</p>
#                     <p><strong>Key Concept:</strong> Polynomial vs exponential runtime</p>
#                     <ul style="list-style: disc; margin-left: 25px; margin-top: 10px;">
#                         <li>n² steps is polynomial = reasonable time</li>
#                         <li><strong>Why I got it wrong:</strong> Saw large numbers and assumed slow, didn't recognize polynomial pattern</li>
#                     </ul>
#                 </div>
#
#                 <div class="mistake-category">
#                     <h4>Q45 – NAND Gate Boolean Expression</h4>
#                     <p><strong>Your Answer:</strong> A ((NOT A) AND (NOT B)) | <strong>Correct:</strong> D (NOT (A AND B))</p>
#                     <p><strong>Key Concept:</strong> NAND is the opposite of AND</p>
#                     <ul style="list-style: disc; margin-left: 25px; margin-top: 10px;">
#                         <li>False only when both true = NOT(A AND B)</li>
#                         <li><strong>Why I got it wrong:</strong> Applied NOT to each input separately instead of to the AND result</li>
#                     </ul>
#                 </div>
#
#                 <div class="mistake-category">
#                     <h4>Q47 – Decrypting Public Key Messages</h4>
#                     <p><strong>Your Answer:</strong> B (sender's private) | <strong>Correct:</strong> D (recipient's private)</p>
#                     <p><strong>Key Concept:</strong> Public/private key pair usage</p>
#                     <ul style="list-style: disc; margin-left: 25px; margin-top: 10px;">
#                         <li>Encrypt with public key, decrypt with matching private key</li>
#                         <li><strong>Why I got it wrong:</strong> Thought sender was involved in decryption, forgot it's recipient's key pair</li>
#                     </ul>
#                 </div>
#
#                 <div class="mistake-category">
#                     <h4>Q52 – Palindrome Algorithm Order</h4>
#                     <p><strong>Your Answer:</strong> B (II only) | <strong>Correct:</strong> C (II and III)</p>
#                     <p><strong>Key Concept:</strong> Step dependencies in algorithms</p>
#                     <ul style="list-style: disc; margin-left: 25px; margin-top: 10px;">
#                         <li>Must identify palindromes before shortening, but sorting can happen anywhere</li>
#                         <li><strong>Why I got it wrong:</strong> Didn't realize sorting first still works since palindrome check comes before shorten</li>
#                     </ul>
#                 </div>
#
#                 <div class="mistake-category">
#                     <h4>Q54 – Generalizing Procedures</h4>
#                     <p><strong>Your Answer:</strong> B (Power(n) = n²) | <strong>Correct:</strong> D (Power(n,m) = n^m)</p>
#                     <p><strong>Key Concept:</strong> Creating flexible procedures from specific ones</p>
#                     <ul style="list-style: disc; margin-left: 25px; margin-top: 10px;">
#                         <li>Need two parameters to generalize all power operations</li>
#                         <li><strong>Why I got it wrong:</strong> Made it specific to squaring instead of fully generalizing with exponent parameter</li>
#                     </ul>
#                 </div>
#
#                 <div class="mistake-category">
#                     <h4>Q55 – Boolean Expression Bug</h4>
#                     <p><strong>Your Answer:</strong> A (returns true for "y") | <strong>Correct:</strong> B (always true)</p>
#                     <p><strong>Key Concept:</strong> OR conditions with single variable</p>
#                     <ul style="list-style: disc; margin-left: 25px; margin-top: 10px;">
#                         <li>(response = "y") OR (response = "n") is always true</li>
#                         <li><strong>Why I got it wrong:</strong> Didn't realize the logic flaw - one of those conditions must be true</li>
#                     </ul>
#                 </div>
#
#                 <div class="mistake-category">
#                     <h4>Q63 – Debugging Prime Counter (SELECT TWO)</h4>
#                     <p><strong>Your Answer:</strong> D only | <strong>Correct:</strong> B AND D</p>
#                     <p><strong>Key Concept:</strong> Finding all bugs in flawed code</p>
#                     <ul style="list-style: disc; margin-left: 25px; margin-top: 10px;">
#                         <li>Line 4 resets count every iteration, Line 9 increments for all numbers</li>
#                         <li><strong>Why I got it wrong:</strong> Found one bug but didn't look for additional errors</li>
#                     </ul>
#                 </div>
#
#                 <div class="mistake-category">
#                     <h4>Q64 – Cloud Computing Impact (SELECT TWO)</h4>
#                     <p><strong>Your Answer:</strong> A | <strong>Correct:</strong> B AND C</p>
#                     <p><strong>Key Concept:</strong> Multiple effects of cloud technology</p>
#                     <ul style="list-style: disc; margin-left: 25px; margin-top: 10px;">
#                         <li>Enhances collaboration, introduces security risks</li>
#                         <li><strong>Why I got it wrong:</strong> Picked redundancy elimination which is wrong - cloud needs redundancy for reliability</li>
#                     </ul>
#                 </div>
#
#                 <div class="mistake-category">
#                     <h4>Q65 – Multiply Bug Conditions (SELECT TWO)</h4>
#                     <p><strong>Your Answer:</strong> C only | <strong>Correct:</strong> B AND D</p>
#                     <p><strong>Key Concept:</strong> Testing with negative values</p>
#                     <ul style="list-style: disc; margin-left: 25px; margin-top: 10px;">
#                         <li>Loop fails when y is negative (counter never reaches negative target)</li>
#                         <li><strong>Why I got it wrong:</strong> Tested x negative with y positive (which works), didn't test y negative cases</li>
#                     </ul>
#                 </div>
#
#                 <h3 style="margin-top: 35px;">Common Mistake Patterns</h3>
#
#                 <div class="mistake-category" style="border-left-color: #f59e0b;">
#                     <h4>Missing "SELECT TWO" (3 times)</h4>
#                     <p><strong>Questions:</strong> Q63, Q64, Q65</p>
#                     <p><strong>Fix:</strong> Circle "TWO" in the question immediately</p>
#                 </div>
#
#                 <div class="mistake-category" style="border-left-color: #f59e0b;">
#                     <h4>Not Tracing Fully (4 times)</h4>
#                     <p><strong>Questions:</strong> Q14, Q26, Q31, Q52</p>
#                     <p><strong>Fix:</strong> Use scratch paper to trace every step</p>
#                 </div>
#
#                 <div class="mistake-category" style="border-left-color: #f59e0b;">
#                     <h4>Boolean Logic Errors (4 times)</h4>
#                     <p><strong>Questions:</strong> Q33, Q45, Q55, Q65</p>
#                     <p><strong>Fix:</strong> Write truth table for anything complex</p>
#                 </div>
#
#                 <div class="mistake-category" style="border-left-color: #f59e0b;">
#                     <h4>Math/Exponents (2 times)</h4>
#                     <p><strong>Questions:</strong> Q12, Q42</p>
#                     <p><strong>Fix:</strong> Write calculations out, don't do mental math</p>
#                 </div>
#
#                 <div class="mistake-category" style="border-left-color: #f59e0b;">
#                     <h4>Reading Too Fast (3 times)</h4>
#                     <p><strong>Questions:</strong> Q16, Q41, Q47</p>
#                     <p><strong>Fix:</strong> Highlight critical words before answering</p>
#                 </div>
#
#                 <div class="mistake-category" style="border-left-color: #f59e0b;">
#                     <h4>Incomplete Counting (2 times)</h4>
#                     <p><strong>Questions:</strong> Q30, Q43</p>
#                     <p><strong>Fix:</strong> Count everything explicitly on paper</p>
#                 </div>
#
#                 <h3 style="margin-top: 35px;">📋 My Study Plan</h3>
#                 <ul class="sprint-list">
#                     <li><strong>Practice tracing</strong> - 10 algorithm problems traced on paper</li>
#                     <li><strong>Truth tables drill</strong> - Create tables for 5 complex boolean expressions</li>
#                     <li><strong>Read questions twice</strong> - Mark all "TWO", "LEAST", "NOT" keywords</li>
#                     <li><strong>Test negative numbers</strong> - Always try negative/zero/boundary cases</li>
#                     <li><strong>Review compression</strong> - Lossy vs lossless, when data is recoverable</li>
#                     <li><strong>Binary/exponents</strong> - Review powers of 2, exponential vs linear growth</li>
#                 </ul>
#             </div>
#
#             <!-- Final Thoughts -->
#             <div class="section">
#                 <h2>💭 Final Thoughts</h2>
#                 <ul class="collab-list">
#                     <li>I really enjoyed the teamwork in this class and how everyone collaborated on projects</li>
#                     <li>I'm thankful for the support and guidance from the TAs throughout the course</li>
#                     <li>The Night at the Museum project was a favorite of mine because it allowed me to be creative and apply what I learned</li>
#                     <li>I feel that I grew a lot in this class, not just in coding skills, but also in problem-solving and thinking algorithmically</li>
#                     <li>Overall, this class was challenging but rewarding, and I'm proud of the progress I made</li>
#                 </ul>
#             </div>
#
#             <!-- Final Conclusion -->
#             <div class="conclusion">
#                 <strong>Looking back on this year, I've transformed from someone who just followed instructions to a confident programmer who understands the "why" behind the code.</strong><br><br>
#                 I've learned to think algorithmically, collaborate effectively, and create projects I'm truly proud of. The journey from the Tools Sprint to the West Coast Travel Quest showed me that coding is both logical and creative.<br><br>
#                 <strong>I'm excited to continue this journey and see where computer science takes me next! 🌟</strong>
#             </div>
#         </div>
#     </div>
#
#     <script>
#         const images = [
#             "images/ntm.png",
#             "images/ntm2.png"
#         ];
#         let index = 0;
#         const slide = document.getElementById("slide");
#
#         function showImage(i) {
#             slide.src = images[i];
#         }
#
#         function nextImage() {
#             index = (index + 1) % images.length;
#             showImage(index);
#         }
#
#         function prevImage() {
#             index = (index - 1 + images.length) % images.length;
#             showImage(index);
#         }
#     </script>
# </body>
# </html>
